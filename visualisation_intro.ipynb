# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthi200221/classroompractice/blob/main/visualisation_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Universities.csv')

# %%
plt.hist(df['Accept'])
plt.show()

# %%
plt.hist(df['Accept'])
plt.xlabel('Accept')
plt.ylabel('count')
plt.title('Histogram')
plt.show()

# %%
plt.hist(df['SAT'])
plt.show()

# %%
sns.histplot(df['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
sns.histplot(df['Accept'])
plt.show()
